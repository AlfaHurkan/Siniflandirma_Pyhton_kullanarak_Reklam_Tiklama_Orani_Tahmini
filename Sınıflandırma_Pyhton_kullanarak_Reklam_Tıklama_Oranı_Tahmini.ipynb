# %% [markdown]
# ### Reklam Tıklama Oranı, reklamınızı kaç kullanıcının tıkladığının, reklamınızı kaç kullanıcının görüntülediğine oranıdır.
# ### Örneğin 100 kullanıcıdan 5'i youtube videosu izlerken reklama tıklıyor. Yani bu durumda youtube reklamının TO'su %5 olacaktır.
# ### Tıklama oranını analiz etmek, şirketlerin hedef kitleleri için en iyi reklamı bulmalarına yardımcı olur.
# ### Dolayısıyla, Reklam tıklama oranını Makine Öğrenimi ile nasıl analiz edip tahmin edeceğinizi öğrenmek istiyorsanız bu çalışma tam size göre.
# ### Bu makale size Python kullanarak Makine Öğrenimi ile Reklam Tıklama Oranı tahmini konusunda yol gösterecektir .

# %%
#pip install pycaret

# %%
import pandas as pd

# %%
# Classification

# %%
df=pd.read_csv('ad_10000records.csv')

# %%
df.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 0                     62.26  32.0     69481.85                172.83
# 1                     41.73  31.0     61840.26                207.17
# 2                     44.40  30.0     57877.15                172.83
# 3                     59.88  28.0     56180.93                207.17
# 4                     49.21  30.0     54324.73                201.58
#
#                          Ad Topic Line             City  Gender  \
# 0      Decentralized real-time circuit         Lisafort    Male
# 1       Optional full-range projection  West Angelabury    Male
# 2  Total 5thgeneration standardization        Reyesfurt  Female
# 3          Balanced empowering success      New Michael  Female
# 4  Total 5thgeneration standardization     West Richard  Female
#
#                         Country            Timestamp  Clicked on Ad
# 0  Svalbard & Jan Mayen Islands  2016-06-09 21:43:05              0
# ...

# %%
from pycaret.classification import*

# %%
setup(df,target='Clicked on Ad')
# Out:
# <style type="text/css">
# #T_c53ee_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c53ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c53ee_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c53ee_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c53ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c53ee_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c53ee_row0_col1" class="data row0 col1" >4269</td>
#     </tr>
#     <tr>
#       <th id="T_c53ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c53ee_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c53ee_row1_col1" class="data row1 col1" >Clicked on Ad</td>
#     </tr>
#     <tr>
#       <th id="T_c53ee_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_db938 th {
#   text-align: left;
# }
# ...

# %%
best_model=create_model('ridge')
# Out:
# <style type="text/css">
# #T_297b5_row10_col0, #T_297b5_row10_col1, #T_297b5_row10_col2, #T_297b5_row10_col3, #T_297b5_row10_col4, #T_297b5_row10_col5, #T_297b5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_297b5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_297b5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_297b5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_297b5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_297b5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_297b5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_297b5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_297b5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(best_model,plot='feature')
